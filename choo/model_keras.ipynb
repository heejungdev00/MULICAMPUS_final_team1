# %%
'''
https://www.kaggle.com/code/aiinradiology/rsna-model
'''
# Out:
# '\nhttps://www.kaggle.com/code/aiinradiology/rsna-model\n'

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import pydicom
import cv2 
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # 필요한 만큼만 메모리를 사용하도록 설정
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            
        # 특정 GPU에 연산을 할당
        tf.config.set_visible_devices(gpus[0], 'GPU')
        
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
        
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPU

# %%
train_df = pd.read_pickle('train_data.pkl')

# %%
train_df.head()
# Out:
#          study_id   series_id  instance_number                    condition  \
# 46219  4075603869  1361414844                8        Spinal Canal Stenosis
# 3641    314041963   277371578               12        Spinal Canal Stenosis
# 25382  2288221191  1504692102               13  Right Subarticular Stenosis
# 45671  4029974537  2684154860               37  Right Subarticular Stenosis
# 47246  4163587601  3190560134               41  Right Subarticular Stenosis
#
#        level           x           y  category  \
# 46219  L3/L4  180.215054  145.519713         1
# 3641   L1/L2  376.057300  114.386185         1
# 25382  L2/L3  292.706422  343.905636         1
# 45671  L5/S1  195.500000  250.128440         1
# 47246  L5/S1  142.390671  161.399417         0
#
#                                          img_file_path  \
# 46219   spine/train_images/4075603869/1361414844/8.dcm
# 3641     spine/train_images/314041963/277371578/12.dcm
# 25382  spine/train_images/2288221191/1504692102/13.dcm
# 45671  spine/train_images/4029974537/2684154860/37.dcm
# 47246  spine/train_images/4163587601/3190560134/41.dcm
#
#                                         processed_images
# 46219  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 3641   b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 25382  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 45671  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 47246  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...

# %%
val_df= pd.read_pickle('val_data.pkl')
val_df.head()
# Out:
#          study_id   series_id  instance_number  \
# 11118   984887785  3830185810                6
# 44346  3895795003  4014059471                7
# 32761  2888359875  2906456873               13
# 43677  3859825215  3632938463               13
# 22510  2026420722  2823687618                4
#
#                              condition  level           x           y  \
# 11118  Left Neural Foraminal Narrowing  L4/L5  161.786988  197.361854
# 44346            Spinal Canal Stenosis  L4/L5  144.424779  165.522124
# 32761       Left Subarticular Stenosis  L4/L5  274.669492  257.084746
# 43677  Left Neural Foraminal Narrowing  L5/S1  239.483871  303.362429
# 22510  Left Neural Foraminal Narrowing  L4/L5  175.771785  324.564481
#
#        category                                    img_file_path  \
# 11118         2    spine/train_images/984887785/3830185810/6.dcm
# 44346         1   spine/train_images/3895795003/4014059471/7.dcm
# 32761         2  spine/train_images/2888359875/2906456873/13.dcm
# 43677         0  spine/train_images/3859825215/3632938463/13.dcm
# 22510         1   spine/train_images/2026420722/2823687618/4.dcm
#
#                                         processed_images
# 11118  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 44346  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 32761  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 43677  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...
# 22510  b'\x80\x04\x95\x83\x00\x00\x00\x00\x00\x00\x00...

# %%
print(f"The training data loaded sucessfully. The train data has {train_df.shape[0]} rows and {train_df.shape[1]} columns.")
print(f"The tvalidatin data loaded sucessfully. The validation data has {val_df.shape[0]} rows and {val_df.shape[1]} columns.")
# Out:
# The training data loaded sucessfully. The train data has 38925 rows and 10 columns.
# The tvalidatin data loaded sucessfully. The validation data has 9732 rows and 10 columns.

# %%
# 사용자 정의 손실 함수를 정의합니다. keras 라이브러리에서 백킹된 함수를 가져올 것입니다. 
# 이 손실 함수는 우리가 완전히 채워지도록 보장합니다
# 이 경기의 요구사항(특정 체중에 대한 것)

# %%
import tensorflow.keras.backend as K
def weighted_log_loss(y_true, y_pred):
    class_weights = K.constant([1.0, 2.0, 4.0])
    y_true = K.cast(y_true, y_pred.dtype)
    weights = K.sum(y_true * class_weights, axis=-1)
    loss = K.sum(y_true * K.log(y_pred + K.epsilon()), axis=-1)
    weighted_loss = -weights * loss
    return K.mean(weighted_loss)

# %%
# train_data 및 val_data가 'img_file_path' 및 'category' 열이 있는 DataFrame이라고 가정
train_df['category'] = train_df['category'].astype(int)
val_df['category'] = val_df['category'].astype(int)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38925 entries, 46219 to 22933
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   study_id          38925 non-null  int64
#  1   series_id         38925 non-null  int64
#  2   instance_number   38925 non-null  int64
#  3   condition         38925 non-null  object
#  4   level             38925 non-null  object
#  5   x                 38925 non-null  float64
#  6   y                 38925 non-null  float64
#  7   category          38925 non-null  int32
#  8   img_file_path     38925 non-null  object
#  9   processed_images  38925 non-null  object
# dtypes: float64(2), int32(1), int64(3), object(4)
# memory usage: 3.1+ MB

# %%
val_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9732 entries, 11118 to 30476
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   study_id          9732 non-null   int64
#  1   series_id         9732 non-null   int64
#  2   instance_number   9732 non-null   int64
#  3   condition         9732 non-null   object
#  4   level             9732 non-null   object
#  5   x                 9732 non-null   float64
#  6   y                 9732 non-null   float64
#  7   category          9732 non-null   int32
#  8   img_file_path     9732 non-null   object
#  9   processed_images  9732 non-null   object
# dtypes: float64(2), int32(1), int64(3), object(4)
# memory usage: 798.3+ KB

# %%
# We will create custom data generator because the pakaged imagedata generator which comes with keras do not have option of creating check points.
# out data is big and by adding check points we will be saivng the progress of the model everytime it runs even if it fails to rune all the epochs (due various reasons such internet failure)

from tensorflow.keras.utils import Sequence
from tensorflow.keras.preprocessing.image import ImageDataGenerator

class DicomDataGenerator(Sequence):
    def __init__(self, dataframe, x_col, y_col, batch_size, target_size, shuffle=True, augment=False):
        self.dataframe = dataframe
        self.x_col = x_col
        self.y_col = y_col
        self.batch_size = batch_size
        self.target_size = target_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()
        
        self.datagen = ImageDataGenerator(
            rotation_range=20,
            zoom_range=0.15,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.15,
            horizontal_flip=True,
            fill_mode="nearest"
        )

    def __len__(self):
        return int(np.floor(len(self.dataframe) / self.batch_size))

    def __getitem__(self, index):
        batch = self.dataframe.iloc[index*self.batch_size:(index+1)*self.batch_size]
        x, y = self.__data_generation(batch)
        return x, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.dataframe))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, batch):
        images = []
        labels = []

        for _, row in batch.iterrows():
            dicom_path = row[self.x_col]
            dicom = pydicom.dcmread(dicom_path)
            image = dicom.pixel_array
            image = cv2.resize(image, self.target_size)
            image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
            image = image.astype('float32') / 255.0
            image = np.expand_dims(image, axis=-1)
            if self.augment:
                image = self.datagen.random_transform(image)
            images.append(image)
            labels.append(row[self.y_col])
        
        x = np.array(images)
        y = tf.keras.utils.to_categorical(labels, num_classes=3)
        return x, y

# Assuming train_data and val_data are your DataFrames with 'img_file_path' and 'category' columns
train_df['category'] = train_df['category'].astype(int)
val_df['category'] = val_df['category'].astype(int)

# Create data generators
train_generator = DicomDataGenerator(
    dataframe=train_df,
    x_col='img_file_path',
    y_col='category',
    batch_size=32,
    target_size=(224, 224),
    shuffle=True,
    augment=True
)

val_generator = DicomDataGenerator(
    dataframe=val_df,
    x_col='img_file_path',
    y_col='category',
    batch_size=32,
    target_size=(224, 224),
    shuffle=False,
    augment=False
)

# %%
#  Buidling model.

from tensorflow.keras.layers import Input

# Model Architecture
model = tf.keras.Sequential([
    Input(shape=(224, 224, 1)),  # Define input shape here
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # Adjust the output layer based on the number of classes
])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LambdaCallback
from tensorflow.keras.models import load_model

# Define the checkpoint callback for best loss
checkpoint_loss = ModelCheckpoint('model_checkpoint_best_loss.weights.h5', 
                                  save_best_only=True, save_weights_only=True, 
                                  monitor='val_loss', mode='min', verbose=1)

# Define the checkpoint callback for best accuracy
checkpoint_accuracy = ModelCheckpoint('model_checkpoint_best_accuracy.weights.h5', 
                                      save_best_only=True, save_weights_only=True, 
                                      monitor='val_accuracy', mode='max', verbose=1)

# Save model after each epoch
save_after_epoch = LambdaCallback(on_epoch_end=lambda epoch, logs: model.save('model_checkpoint_epoch.h5'))

# Compile the Model with the custom weighted log loss
model.compile(optimizer='adam', loss=weighted_log_loss, metrics=['accuracy'])

# Load the last saved weights if they exist
try:
    model.load_weights('model_checkpoint_epoch.h5')
    print("Model weights loaded from the last checkpoint.")
except:
    try:
        model.load_weights('model_checkpoint_best_loss.weights.h5')
        print("Model weights loaded from best validation loss checkpoint.")
    except:
        try:
            model.load_weights('model_checkpoint_best_accuracy.weights.h5')
            print("Model weights loaded from best validation accuracy checkpoint.")
        except:
            print("No checkpoint found. Starting training from scratch.")

# Train the model with both checkpoint callbacks
history = model.fit(train_generator, epochs=50, validation_data=val_generator, 
                    callbacks=[checkpoint_loss, checkpoint_accuracy, save_after_epoch])

# Save the fully trained model
model.save('my_trained_model.h5')
# Out:
# Model weights loaded from the last checkpoint.
# Epoch 1/50
# 1216/1216 [==============================] - ETA: 0s - loss: 1.0393 - accuracy: 0.7833
# Epoch 1: val_loss improved from inf to 0.97544, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.79153, saving model to model_checkpoint_best_accuracy.weights.h5
# 1216/1216 [==============================] - 694s 564ms/step - loss: 1.0393 - accuracy: 0.7833 - val_loss: 0.9754 - val_accuracy: 0.7915
# Epoch 2/50
# 1216/1216 [==============================] - ETA: 0s - loss: 1.0226 - accuracy: 0.7852
# Epoch 2: val_loss did not improve from 0.97544
#
# Epoch 2: val_accuracy did not improve from 0.79153
# 1216/1216 [==============================] - 534s 439ms/step - loss: 1.0226 - accuracy: 0.7852 - val_loss: 0.9969 - val_accuracy: 0.7857
# Epoch 3/50
# 1216/1216 [==============================] - ETA: 0s - loss: 1.0231 - accuracy: 0.7854
# Epoch 3: val_loss improved from 0.97544 to 0.97515, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 3: val_accuracy improved from 0.79153 to 0.79266, saving model to model_checkpoint_best_accuracy.weights.h5
# 1216/1216 [==============================] - 488s 401ms/step - loss: 1.0231 - accuracy: 0.7854 - val_loss: 0.9751 - val_accuracy: 0.7927
# Epoch 4/50
# 1216/1216 [==============================] - ETA: 0s - loss: 1.0116 - accuracy: 0.7865
# Epoch 4: val_loss improved from 0.97515 to 0.97201, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 4: val_accuracy did not improve from 0.79266
# 1216/1216 [==============================] - 487s 400ms/step - loss: 1.0116 - accuracy: 0.7865 - val_loss: 0.9720 - val_accuracy: 0.7861
# Epoch 5/50
# 1216/1216 [==============================] - ETA: 0s - loss: 1.0070 - accuracy: 0.7864
# Epoch 5: val_loss improved from 0.97201 to 0.95944, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 5: val_accuracy improved from 0.79266 to 0.79276, saving model to model_checkpoint_best_accuracy.weights.h5
# 1216/1216 [==============================] - 485s 399ms/step - loss: 1.0070 - accuracy: 0.7864 - val_loss: 0.9594 - val_accuracy: 0.7928
# Epoch 6/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9997 - accuracy: 0.7875
# Epoch 6: val_loss improved from 0.95944 to 0.95176, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 6: val_accuracy did not improve from 0.79276
# 1216/1216 [==============================] - 487s 400ms/step - loss: 0.9997 - accuracy: 0.7875 - val_loss: 0.9518 - val_accuracy: 0.7921
# Epoch 7/50
# 1216/1216 [==============================] - ETA: 0s - loss: 1.0003 - accuracy: 0.7873
# Epoch 7: val_loss improved from 0.95176 to 0.94254, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 7: val_accuracy did not improve from 0.79276
# 1216/1216 [==============================] - 491s 404ms/step - loss: 1.0003 - accuracy: 0.7873 - val_loss: 0.9425 - val_accuracy: 0.7924
# Epoch 8/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9901 - accuracy: 0.7876
# Epoch 8: val_loss did not improve from 0.94254
#
# Epoch 8: val_accuracy did not improve from 0.79276
# 1216/1216 [==============================] - 489s 402ms/step - loss: 0.9901 - accuracy: 0.7876 - val_loss: 0.9638 - val_accuracy: 0.7916
# Epoch 9/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9804 - accuracy: 0.7881
# Epoch 9: val_loss did not improve from 0.94254
#
# Epoch 9: val_accuracy improved from 0.79276 to 0.79410, saving model to model_checkpoint_best_accuracy.weights.h5
# 1216/1216 [==============================] - 479s 394ms/step - loss: 0.9804 - accuracy: 0.7881 - val_loss: 0.9649 - val_accuracy: 0.7941
# Epoch 10/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9785 - accuracy: 0.7882
# Epoch 10: val_loss did not improve from 0.94254
#
# Epoch 10: val_accuracy did not improve from 0.79410
# 1216/1216 [==============================] - 477s 392ms/step - loss: 0.9785 - accuracy: 0.7882 - val_loss: 0.9451 - val_accuracy: 0.7937
# Epoch 11/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9777 - accuracy: 0.7883
# Epoch 11: val_loss did not improve from 0.94254
#
# Epoch 11: val_accuracy improved from 0.79410 to 0.79544, saving model to model_checkpoint_best_accuracy.weights.h5
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9777 - accuracy: 0.7883 - val_loss: 0.9449 - val_accuracy: 0.7954
# Epoch 12/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9760 - accuracy: 0.7889
# Epoch 12: val_loss did not improve from 0.94254
#
# Epoch 12: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9760 - accuracy: 0.7889 - val_loss: 0.9487 - val_accuracy: 0.7947
# Epoch 13/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9690 - accuracy: 0.7887
# Epoch 13: val_loss did not improve from 0.94254
#
# Epoch 13: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 477s 392ms/step - loss: 0.9690 - accuracy: 0.7887 - val_loss: 0.9430 - val_accuracy: 0.7891
# Epoch 14/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9665 - accuracy: 0.7888
# Epoch 14: val_loss improved from 0.94254 to 0.93639, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 14: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 3722s 3s/step - loss: 0.9665 - accuracy: 0.7888 - val_loss: 0.9364 - val_accuracy: 0.7953
# Epoch 15/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9619 - accuracy: 0.7893
# Epoch 15: val_loss did not improve from 0.93639
#
# Epoch 15: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9619 - accuracy: 0.7893 - val_loss: 0.9533 - val_accuracy: 0.7928
# Epoch 16/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9600 - accuracy: 0.7897
# Epoch 16: val_loss did not improve from 0.93639
#
# Epoch 16: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9600 - accuracy: 0.7897 - val_loss: 0.9374 - val_accuracy: 0.7914
# Epoch 17/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9613 - accuracy: 0.7885
# Epoch 17: val_loss improved from 0.93639 to 0.92860, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 17: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 476s 391ms/step - loss: 0.9613 - accuracy: 0.7885 - val_loss: 0.9286 - val_accuracy: 0.7952
# Epoch 18/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9539 - accuracy: 0.7898
# Epoch 18: val_loss did not improve from 0.92860
#
# Epoch 18: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 477s 392ms/step - loss: 0.9539 - accuracy: 0.7898 - val_loss: 0.9296 - val_accuracy: 0.7940
# Epoch 19/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9552 - accuracy: 0.7891
# Epoch 19: val_loss improved from 0.92860 to 0.92253, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 19: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 481s 396ms/step - loss: 0.9552 - accuracy: 0.7891 - val_loss: 0.9225 - val_accuracy: 0.7943
# Epoch 20/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9525 - accuracy: 0.7890
# Epoch 20: val_loss improved from 0.92253 to 0.92133, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 20: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 482s 396ms/step - loss: 0.9525 - accuracy: 0.7890 - val_loss: 0.9213 - val_accuracy: 0.7922
# Epoch 21/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9443 - accuracy: 0.7913
# Epoch 21: val_loss improved from 0.92133 to 0.92071, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 21: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 472s 388ms/step - loss: 0.9443 - accuracy: 0.7913 - val_loss: 0.9207 - val_accuracy: 0.7914
# Epoch 22/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9442 - accuracy: 0.7903
# Epoch 22: val_loss improved from 0.92071 to 0.91999, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 22: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 474s 390ms/step - loss: 0.9442 - accuracy: 0.7903 - val_loss: 0.9200 - val_accuracy: 0.7907
# Epoch 23/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9514 - accuracy: 0.7906
# Epoch 23: val_loss did not improve from 0.91999
#
# Epoch 23: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 14989s 12s/step - loss: 0.9514 - accuracy: 0.7906 - val_loss: 0.9206 - val_accuracy: 0.7940
# Epoch 24/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9469 - accuracy: 0.7905
# Epoch 24: val_loss did not improve from 0.91999
#
# Epoch 24: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 482s 397ms/step - loss: 0.9469 - accuracy: 0.7905 - val_loss: 0.9279 - val_accuracy: 0.7920
# Epoch 25/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9510 - accuracy: 0.7902
# Epoch 25: val_loss did not improve from 0.91999
#
# Epoch 25: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 510s 419ms/step - loss: 0.9510 - accuracy: 0.7902 - val_loss: 0.9287 - val_accuracy: 0.7951
# Epoch 26/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9459 - accuracy: 0.7903
# Epoch 26: val_loss did not improve from 0.91999
#
# Epoch 26: val_accuracy did not improve from 0.79544
# 1216/1216 [==============================] - 561s 462ms/step - loss: 0.9459 - accuracy: 0.7903 - val_loss: 0.9414 - val_accuracy: 0.7875
# Epoch 27/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9440 - accuracy: 0.7902
# Epoch 27: val_loss improved from 0.91999 to 0.91216, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 27: val_accuracy improved from 0.79544 to 0.79554, saving model to model_checkpoint_best_accuracy.weights.h5
# 1216/1216 [==============================] - 479s 394ms/step - loss: 0.9440 - accuracy: 0.7902 - val_loss: 0.9122 - val_accuracy: 0.7955
# Epoch 28/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9420 - accuracy: 0.7899
# Epoch 28: val_loss improved from 0.91216 to 0.91215, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 28: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 476s 391ms/step - loss: 0.9420 - accuracy: 0.7899 - val_loss: 0.9121 - val_accuracy: 0.7936
# Epoch 29/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9357 - accuracy: 0.7922
# Epoch 29: val_loss improved from 0.91215 to 0.91164, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 29: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9357 - accuracy: 0.7922 - val_loss: 0.9116 - val_accuracy: 0.7914
# Epoch 30/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9400 - accuracy: 0.7912
# Epoch 30: val_loss did not improve from 0.91164
#
# Epoch 30: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 477s 392ms/step - loss: 0.9400 - accuracy: 0.7912 - val_loss: 0.9167 - val_accuracy: 0.7942
# Epoch 31/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9380 - accuracy: 0.7912
# Epoch 31: val_loss did not improve from 0.91164
#
# Epoch 31: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 476s 391ms/step - loss: 0.9380 - accuracy: 0.7912 - val_loss: 0.9138 - val_accuracy: 0.7930
# Epoch 32/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9302 - accuracy: 0.7913
# Epoch 32: val_loss did not improve from 0.91164
#
# Epoch 32: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 390ms/step - loss: 0.9302 - accuracy: 0.7913 - val_loss: 0.9260 - val_accuracy: 0.7952
# Epoch 33/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9332 - accuracy: 0.7919
# Epoch 33: val_loss did not improve from 0.91164
#
# Epoch 33: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9332 - accuracy: 0.7919 - val_loss: 0.9117 - val_accuracy: 0.7939
# Epoch 34/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9295 - accuracy: 0.7918
# Epoch 34: val_loss did not improve from 0.91164
#
# Epoch 34: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9295 - accuracy: 0.7918 - val_loss: 0.9708 - val_accuracy: 0.7926
# Epoch 35/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9416 - accuracy: 0.7903
# Epoch 35: val_loss improved from 0.91164 to 0.90634, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 35: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 472s 388ms/step - loss: 0.9416 - accuracy: 0.7903 - val_loss: 0.9063 - val_accuracy: 0.7945
# Epoch 36/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9330 - accuracy: 0.7918
# Epoch 36: val_loss improved from 0.90634 to 0.90153, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 36: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9330 - accuracy: 0.7918 - val_loss: 0.9015 - val_accuracy: 0.7928
# Epoch 37/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9360 - accuracy: 0.7919
# Epoch 37: val_loss did not improve from 0.90153
#
# Epoch 37: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 389ms/step - loss: 0.9360 - accuracy: 0.7919 - val_loss: 0.9038 - val_accuracy: 0.7953
# Epoch 38/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9282 - accuracy: 0.7906
# Epoch 38: val_loss did not improve from 0.90153
#
# Epoch 38: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 389ms/step - loss: 0.9282 - accuracy: 0.7906 - val_loss: 0.9061 - val_accuracy: 0.7947
# Epoch 39/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9321 - accuracy: 0.7915
# Epoch 39: val_loss did not improve from 0.90153
#
# Epoch 39: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 476s 391ms/step - loss: 0.9321 - accuracy: 0.7915 - val_loss: 0.9189 - val_accuracy: 0.7933
# Epoch 40/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9278 - accuracy: 0.7915
# Epoch 40: val_loss did not improve from 0.90153
#
# Epoch 40: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 475s 391ms/step - loss: 0.9278 - accuracy: 0.7915 - val_loss: 0.9102 - val_accuracy: 0.7896
# Epoch 41/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9210 - accuracy: 0.7924
# Epoch 41: val_loss did not improve from 0.90153
#
# Epoch 41: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9210 - accuracy: 0.7924 - val_loss: 0.9028 - val_accuracy: 0.7928
# Epoch 42/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9213 - accuracy: 0.7913
# Epoch 42: val_loss did not improve from 0.90153
#
# Epoch 42: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 390ms/step - loss: 0.9213 - accuracy: 0.7913 - val_loss: 0.9033 - val_accuracy: 0.7928
# Epoch 43/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9200 - accuracy: 0.7925
# Epoch 43: val_loss did not improve from 0.90153
#
# Epoch 43: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 389ms/step - loss: 0.9200 - accuracy: 0.7925 - val_loss: 0.9157 - val_accuracy: 0.7954
# Epoch 44/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9222 - accuracy: 0.7919
# Epoch 44: val_loss did not improve from 0.90153
#
# Epoch 44: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 390ms/step - loss: 0.9222 - accuracy: 0.7919 - val_loss: 0.9025 - val_accuracy: 0.7954
# Epoch 45/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9213 - accuracy: 0.7914
# Epoch 45: val_loss improved from 0.90153 to 0.89344, saving model to model_checkpoint_best_loss.weights.h5
#
# Epoch 45: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9213 - accuracy: 0.7914 - val_loss: 0.8934 - val_accuracy: 0.7951
# Epoch 46/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9206 - accuracy: 0.7912
# Epoch 46: val_loss did not improve from 0.89344
#
# Epoch 46: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9206 - accuracy: 0.7912 - val_loss: 0.9136 - val_accuracy: 0.7936
# Epoch 47/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9219 - accuracy: 0.7916
# Epoch 47: val_loss did not improve from 0.89344
#
# Epoch 47: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 474s 390ms/step - loss: 0.9219 - accuracy: 0.7916 - val_loss: 0.9112 - val_accuracy: 0.7939
# Epoch 48/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9235 - accuracy: 0.7916
# Epoch 48: val_loss did not improve from 0.89344
#
# Epoch 48: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 473s 389ms/step - loss: 0.9235 - accuracy: 0.7916 - val_loss: 0.8951 - val_accuracy: 0.7935
# Epoch 49/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9182 - accuracy: 0.7919
# Epoch 49: val_loss did not improve from 0.89344
#
# Epoch 49: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9182 - accuracy: 0.7919 - val_loss: 0.9357 - val_accuracy: 0.7953
# Epoch 50/50
# 1216/1216 [==============================] - ETA: 0s - loss: 0.9182 - accuracy: 0.7928
# Epoch 50: val_loss did not improve from 0.89344
#
# Epoch 50: val_accuracy did not improve from 0.79554
# 1216/1216 [==============================] - 475s 390ms/step - loss: 0.9182 - accuracy: 0.7928 - val_loss: 0.8975 - val_accuracy: 0.7928

# %%
# Evaluate the Model
val_loss, val_accuracy = model.evaluate(val_generator)
print(f'Validation Accuracy: {val_accuracy}')
# Out:
# 304/304 [==============================] - 79s 260ms/step - loss: 0.8975 - accuracy: 0.7928
# Validation Accuracy: 0.7927631735801697
