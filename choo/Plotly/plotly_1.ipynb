# %%
'''
https://wikidocs.net/185049
'''
# Out:
# '\nhttps://wikidocs.net/185049\n'

# %%
#pip install plotly==5.11.0

# %%
pip install --upgrade jupyterlab plotly
# Out:
# Requirement already satisfied: jupyterlab in c:\anaconnda3\lib\site-packages (4.0.11)
# Collecting jupyterlab
#   Using cached jupyterlab-4.2.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: plotly in c:\anaconnda3\lib\site-packages (5.11.0)
# Collecting plotly
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: async-lru>=1.0.0 in c:\anaconnda3\lib\site-packages (from jupyterlab) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\anaconnda3\lib\site-packages (from jupyterlab) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\anaconnda3\lib\site-packages (from jupyterlab) (3.1.3)
# Requirement already satisfied: jupyter-core in c:\anaconnda3\lib\site-packages (from jupyterlab) (5.5.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\anaconnda3\lib\site-packages (from jupyterlab) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\anaconnda3\lib\site-packages (from jupyterlab) (2.10.0)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab)
#   Using cached jupyterlab_server-2.27.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in c:\anaconnda3\lib\site-packages (from jupyterlab) (0.2.3)
# Requirement already satisfied: packaging in c:\anaconnda3\lib\site-packages (from jupyterlab) (23.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\anaconnda3\lib\site-packages (from jupyterlab) (68.2.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\anaconnda3\lib\site-packages (from jupyterlab) (6.3.3)
# Requirement already satisfied: traitlets in c:\anaconnda3\lib\site-packages (from jupyterlab) (5.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\anaconnda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: anyio in c:\anaconnda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (4.2.0)
# Requirement already satisfied: certifi in c:\anaconnda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\anaconnda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (3.4)
# Requirement already satisfied: sniffio in c:\anaconnda3\lib\site-packages (from httpx>=0.25.0->jupyterlab) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\anaconnda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\anaconnda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab) (25.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconnda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\anaconnda3\lib\site-packages (from jupyter-core->jupyterlab) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\anaconnda3\lib\site-packages (from jupyter-core->jupyterlab) (305.1)
# Requirement already satisfied: argon2-cffi in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.9.2)
# Requirement already satisfied: overrides in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.14.1)
# Requirement already satisfied: pywinpty in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.17.1)
# Requirement already satisfied: websocket-client in c:\anaconnda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.58.0)
# Requirement already satisfied: babel>=2.10 in c:\anaconnda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\anaconnda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\anaconnda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\anaconnda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.31.0)
# Requirement already satisfied: pytz>=2015.7 in c:\anaconnda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.3.post1)
# Requirement already satisfied: decorator in c:\anaconnda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\anaconnda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\anaconnda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\anaconnda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.15.1)
# Requirement already satisfied: stack-data in c:\anaconnda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: colorama in c:\anaconnda3\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\anaconnda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\anaconnda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\anaconnda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\anaconnda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconnda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\anaconnda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\anaconnda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\anaconnda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\anaconnda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.1.0)
# Requirement already satisfied: defusedxml in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\anaconnda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\anaconnda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconnda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconnda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\anaconnda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: six in c:\anaconnda3\lib\site-packages (from websocket-client->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: webencodings in c:\anaconnda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\anaconnda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\anaconnda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab)
#   Using cached webcolors-24.6.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: wcwidth in c:\anaconnda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in c:\anaconnda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconnda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.5)
# Requirement already satisfied: executing in c:\anaconnda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.3)
# Requirement already satisfied: asttokens in c:\anaconnda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.0.5)
# Requirement already satisfied: pure-eval in c:\anaconnda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: pycparser in c:\anaconnda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\anaconnda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.3)
# Using cached jupyterlab-4.2.3-py3-none-any.whl (11.6 MB)
# Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jupyterlab_server-2.27.2-py3-none-any.whl (59 kB)
# Using cached webcolors-24.6.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, plotly, httpcore, fqdn, httpx, isoduration, jupyterlab-server, jupyterlab
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.11.0
#     Uninstalling plotly-5.11.0:
#       Successfully uninstalled plotly-5.11.0
#   Attempting uninstall: jupyterlab-server
#     Found existing installation: jupyterlab_server 2.25.1
#     Uninstalling jupyterlab_server-2.25.1:
#       Successfully uninstalled jupyterlab_server-2.25.1
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.0.11
#     Uninstalling jupyterlab-4.0.11:
#       Successfully uninstalled jupyterlab-4.0.11
# Successfully installed fqdn-1.5.1 httpcore-1.0.5 httpx-0.27.0 isoduration-20.11.0 jupyterlab-4.2.3 jupyterlab-server-2.27.2 plotly-5.22.0 uri-template-1.3.0 webcolors-24.6.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# notebook 7.0.8 requires jupyterlab<4.1,>=4.0.2, but you have jupyterlab 4.2.3 which is incompatible.

# %%
#pip install kaleido

# %%
#pip install statsmodels

# %%
# 방법 :
# 1. graph_objects 모듈을 활용한 생성
# 2. express 모듈을 활용한 생성

# %%
# graph_objects 모듈 : 그래프를 하나하나 설명하고 직접 지정

# %%
'''
go.Figure(
    data=[데이터]
    layout=go.layout(title, axes, shape, margins)
)

data : 'trace'를  python list형태로 받는다. 
trace : 그리고자 하는 그래프의 타입(bar, scatter, line, box) + 시각화하고자하는 열(raw)를 품고있는 단위
    - go.Bar(x=[1, 2, 3], y=[1, 3, 2]) 가 하나의 Trace

figure 랜더링(2차원의 화상에 광원·위치·색상 등 외부의 정보를 고려하여 사실감을 불어넣어, 3차원 화상을 만드는 과정)
=> fig.show()

'''
# Out:
# "\ngo.Figure(\n    data=[데이터]\n    layout=go.layout(title, axes, shape, margins)\n)\n\ndata : 'trace'를  python list형태로 받는다. \ntrace : 그리고자 하는 그래프의 타입(bar, scatter, line, box) + 시각화하고자하는 열(raw)를 품고있는 단위\n    - go.Bar(x=[1, 2, 3], y=[1, 3, 2]) 가 하나의 Trace\n\nfigure 랜더링(2차원의 화상에 광원·위치·색상 등 외부의 정보를 고려하여 사실감을 불어넣어, 3차원 화상을 만드는 과정)\n=> fig.show()\n\n"

# %%
# graph_objects 패키지를  go 로 불러옴
import plotly.graph_objects as go

# go.Figure() 함수를 활용하여 기본 그래프를 생성
fig = go.Figure(
    # Data 입력
    data=[go.Bar(x=[1, 2, 3], y=[1, 3, 2])],
    # layout 입력
    layout=go.Layout(
        title=go.layout.Title(text="A Figure Specified By A Graph Object")
    )
)
#show하면 내 노트북 (주피터 노트북 등)에 그래프가 나타남.
fig.show()

# %%
# express 모듈을 활용한 그래프 생성
#그래프를 이미 제작되어있는 템플릿으로 빠르게 제작하는 방법 high-level 모듈

# %%
# express 패키지를 px로 불러옴
import plotly.express as px

# %%
# px.bar() 함수를 활용해서 bar chart 생성과 동시에 data, layout 값 입력
fig = px.bar(x=['a','b','c'], y=[1,3,2], title='A Figure Specified By express')

# %%
fig.show()

# %%
'''
지금 현재 px.bar 와 같이 express 를 통해 제작된 템플릿은 아래와 같습니다.

Basics: scatter, line, area, bar, funnel, timeline
Part-of-Whole: pie, sunburst, treemap, icicle, funnel_area
1D Distributions: histogram, box, violin, strip, ecdf
2D Distributions: density_heatmap, density_contour
Matrix or Image Input: imshow
3-Dimensional: scatter_3d, line_3d
Multidimensional: scatter_matrix, parallel_coordinates, parallel_categories
Tile Maps: scatter_mapbox, line_mapbox, choropleth_mapbox, density_mapbox
Outline Maps: scatter_geo, line_geo, choropleth
Polar Charts: scatter_polar, line_polar, bar_polar
Ternary Charts: scatter_ternary, line_ternary
'''
# Out:
# '\n지금 현재 px.bar 와 같이 express 를 통해 제작된 템플릿은 아래와 같습니다.\n\nBasics: scatter, line, area, bar, funnel, timeline\nPart-of-Whole: pie, sunburst, treemap, icicle, funnel_area\n1D Distributions: histogram, box, violin, strip, ecdf\n2D Distributions: density_heatmap, density_contour\nMatrix or Image Input: imshow\n3-Dimensional: scatter_3d, line_3d\nMultidimensional: scatter_matrix, parallel_coordinates, parallel_categories\nTile Maps: scatter_mapbox, line_mapbox, choropleth_mapbox, density_mapbox\nOutline Maps: scatter_geo, line_geo, choropleth\nPolar Charts: scatter_polar, line_polar, bar_polar\nTernary Charts: scatter_ternary, line_ternary\n'

# %%
# 그래프 튜닝 과정 5가지 함수
# add_trace(), update_traces(), update_layout(), update_xaxes(), update_yaxes()

# %%
'''
# add_trace()
fig.add_trace(추가할 trace 입력)
'''
# Out:
# '\n# add_trace()\nfig.add_trace(추가할 trace 입력)\n'

# %%
fig = go.Figure()
fig.show()

# %%
# 빈 Figure에 Trace추가하기
fig.add_trace(go.Bar(x=[1,2,3], y=[1,3,2]))
fig.show()

# %%
# add_trace()
df = px.data.iris()
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
#express를 활용한 scatter plot 생성
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species',
                title='Using The add_trace() method with A Plotly Express Figure')
fig.show()

# %%
fig.add_trace(
    go.Scatter(
        x=[2,4],
        y=[4,8],
        mode='lines',
        line=go.scatter.Line(color='gray'),
        showlegend=False
    )
)
fig.show()

# %%
'''
# update_trace()
update_trace() 함수를 사용하면 이미 생성된 trace의 type, 색, 스타일, 템플릿 등 추가 편집이 가능합니다. 
물론 처음 Trace를 생성할 때 스타일 지정을 해서 생성이 가능하지만 update_trace 를 활용하면 한번에 
모든 Trace의 스타일 업데이트가 가능하여 코드의 길이를 줄일 수 있으며 가독성이 높은 코드구현을 위해 
Trace 생성부 와 Trace 편집부를 나눠서 작성 가능하게 합니다
'''
# Out:
# '\n# update_trace()\nupdate_trace() 함수를 사용하면 이미 생성된 trace의 type, 색, 스타일, 템플릿 등 추가 편집이 가능합니다. \n물론 처음 Trace를 생성할 때 스타일 지정을 해서 생성이 가능하지만 update_trace 를 활용하면 한번에 \n모든 Trace의 스타일 업데이트가 가능하여 코드의 길이를 줄일 수 있으며 가독성이 높은 코드구현을 위해 \nTrace 생성부 와 Trace 편집부를 나눠서 작성 가능하게 합니다\n'

# %%
from plotly.subplots import make_subplots

#subplot 생성
fig = make_subplots(rows=1, cols=2)

# Trace 생성
fig.add_scatter(y=[4, 2, 3.5], mode='markers',
               marker=dict(size=20, color='LightSeaGreen'),
               name='a', row=1, col=1)

fig.add_bar(y=[2,1,3],
           marker=dict(color='MediumPurple'),
           name='b', row=1, col=1)

fig.add_scatter(y=[2, 3.5, 4], mode='markers',
               marker=dict(size=20, color='MediumPurple'),
               name='c', row=1, col=2)

fig.add_bar(y=[1,3,2],
           marker=dict(color='LightSeaGreen'),
           name='d', row=1, col=2)

# 한번에 Bar plot 만 파란색으로 바꾸기
fig.update_traces(marker=dict(color='RoyalBlue'),
                 selector=dict(type='bar'))
fig.show()

'''
총 4개의 trace 생성
update_traces()를 활용하여 barplot만 royalblue로 한번에 변경
'''
# Out:
# '\n총 4개의 trace 생성\nupdate_traces()를 활용하여 barplot만 royalblue로 한번에 변경\n'

# %%
'''
#update_layout()
fig.update_layout(업데이트 내용)
update_layout() 함수를 사용하면 그래프 사이즈, 제목 및 텍스트, 글꼴크기 
와 같은 Trace 외적인 그래프 요소를 업데이트 가능합니다.
'''
# Out:
# '\n#update_layout()\nfig.update_layout(업데이트 내용)\nupdate_layout() 함수를 사용하면 그래프 사이즈, 제목 및 텍스트, 글꼴크기 \n와 같은 Trace 외적인 그래프 요소를 업데이트 가능합니다.\n'

# %%
import plotly.graph_objects as go

# 그래프 생성
fig = go.Figure(data=go.Bar(x=[1,2,3], y=[1,3,2]))

# 타이틀 추가하기
fig.update_layout(title_text='Using update_layout() with Graph Object Figures', title_font_size=30)
fig.show()

# %%
'''
# update_xaxes()/ update_yaxes()
fig.update_xaxes(업데이트 내용)
fig.update_yaxes(업데이트 내용

update_xaxes(), update_yaxes() 함수를 사용하면 각각 X축, Y축에 관한 다양한 편집이 가능합니다. 
ex) 축 타이틀, 축 라인 스타일, 그리드 설정 등
'''
# Out:
# '\n# update_xaxes()/ update_yaxes()\nfig.update_xaxes(업데이트 내용)\nfig.update_yaxes(업데이트 내용\n\nupdate_xaxes(), update_yaxes() 함수를 사용하면 각각 X축, Y축에 관한 다양한 편집이 가능합니다. \nex) 축 타이틀, 축 라인 스타일, 그리드 설정 등\n'

# %%
import plotly.graph_objects as go
import plotly.express as px

# 데이터 생성
df= px.data.tips()
x=df['total_bill']
y=df['tip']

# 그래프 그리기 
fig=go.Figure(data=go.Scatter(x=x,y=y, mode='markers'))

# 축타이틀 추가하기
fig.update_xaxes(title_text='Total Bill ($)')
fig.update_yaxes(title_text='Tip ($)')

fig.show()

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
diamonds = sns.load_dataset('diamonds') # 다이아 데이터셋
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
election = px.data.election()
election.head()
# Out:
#                 district  Coderre  Bergeron  Joly  total    winner     result  \
# 0     101-Bois-de-Liesse     2481      1829  3024   7334      Joly  plurality
# 1  102-Cap-Saint-Jacques     2525      1163  2675   6363      Joly  plurality
# 2   11-Sault-au-Récollet     3348      2770  2532   8650   Coderre  plurality
# 3           111-Mile-End     1734      4782  2514   9030  Bergeron   majority
# 4         112-DeLorimier     1770      5933  3044  10747  Bergeron   majority
#
#    district_id
# 0          101
# 1          102
# 2           11
# 3          111
# 4          112

# %%
# 그래프 사이즈 설정하기

# %%
fig = px.bar(x=['a','b','c'], y=[1,3,2], width=600, height=400)
fig.show()

# %%
fig = go.Figure(data=[go.Bar(x=[1,2,3], y=[1,3,2])],
               layout=go.Layout(width=600, height=400))

#fig.update_layout(width=600, height=400)
fig.show()

# %%
fig = px.bar(x=['a','b','c'], y=[1,3,2])

fig.update_layout(
    width=600,
    height=400,
    margin_l=50,
    margin_r=50,
    margin_b=100,
    margin_t=100,

    paper_bgcolor='LightSteelBlue'
)
fig.show()

# %%
import plotly.express as px

fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2], title="Title 설정하기")
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(
    data=[go.Bar(x=[1, 2, 3], y=[1, 3, 2])],
    layout=go.Layout(title=go.layout.Title(text="Title 설정하기")))
fig.show()

# %%
# express 방법
import plotly.express as px

fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])

fig.update_layout(title_text="타이틀 설정하기")

fig.show()

# %%
# graph_objects  방법
import plotly.graph_objects as go

fig = go.Figure(data=[go.Bar(x=[1, 2, 3], y=[1, 3, 2])])

fig.update_layout(title_text="타이틀 설정하기")

fig.show()

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2], title="Title 설정하기")

# 타이틀 위치 설정부분
fig.update_layout(
                 title_x = 0.5,
                 title_y = 0.9,
                 title_xanchor = "center",
                 title_yanchor = "middle")

fig.show()

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2], title="Title 설정하기")

fig.update_layout(
        # 타이틀 위치 설정 부분
        title_y = 0.9,
        title_x = 0.5,
        title_xanchor = 'center',
        title_yanchor ='middle',
        # 폰트 스타일 추가 부분
        title_font_size = 25,
        title_font_color = "LightSeaGreen",
        title_font_family = "fantasy")

fig.show()

# %%
'''
title_font_size = 폰트 사이즈를 숫자로 입력합니다.
title_font_color = 원하는 색을 지정합니다.
title_font_family =HTML font family로 plotly를 구동하는 web browser에서 지원하는 폰트를 지원합니다. 몇가지 대표적인 폰트는 아래와 같습니다.
1) family-font: 우리가 일반적으로 알고 있는 특정 글꼴
ex) Georgia, arial, 나눔고딕, 궁서, 굴림, Times New Roman, Times, 등

2) generic-font: 비슷한 모양의 글꼴 집합
family-name으로 지정된 글꼴을 사용할 수 없는 경우 브라우저가 비슷한 스타일로 대체 할 수있도록 선언해주는 폰트입니다.
ex) serif, sans-serif, monospace, cursive, fantasy

serif : 삐침 있는 명조계열의 글꼴 모음
sans-serif : 삐침 없는 고딕계열의 글꼴 모음
cursive : 손 필기체 같은 느낌의 글꼴 모음
-monospace : 글자 폭과 간격이 일정한 글꼴 모음
fantasy : 위 폰트들을 제외한 나머지 화려한 글꼴 모음
'''
# Out:
# '\ntitle_font_size = 폰트 사이즈를 숫자로 입력합니다.\ntitle_font_color = 원하는 색을 지정합니다.\ntitle_font_family =HTML font family로 plotly를 구동하는 web browser에서 지원하는 폰트를 지원합니다. 몇가지 대표적인 폰트는 아래와 같습니다.\n1) family-font: 우리가 일반적으로 알고 있는 특정 글꼴\nex) Georgia, arial, 나눔고딕, 궁서, 굴림, Times New Roman, Times, 등\n\n2) generic-font: 비슷한 모양의 글꼴 집합\nfamily-name으로 지정된 글꼴을 사용할 수 없는 경우 브라우저가 비슷한 스타일로 대체 할 수있도록 선언해주는 폰트입니다.\nex) serif, sans-serif, monospace, cursive, fantasy\n\nserif : 삐침 있는 명조계열의 글꼴 모음\nsans-serif : 삐침 없는 고딕계열의 글꼴 모음\ncursive : 손 필기체 같은 느낌의 글꼴 모음\n-monospace : 글자 폭과 간격이 일정한 글꼴 모음\nfantasy : 위 폰트들을 제외한 나머지 화려한 글꼴 모음\n'
