# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Concatenate
from nltk.translate.bleu_score import sentence_bleu
import os
from tensorflow.keras.callbacks import ModelCheckpoint, LambdaCallback, EarlyStopping
from tensorflow.keras.callbacks import Callback

# 데이터 로드
df = pd.read_excel("/content/drive/MyDrive/자연어 처리 학습 피드백.xlsx", names=["각도차이", "피드백"])
angle_differences = df.loc[:, "각도차이"].apply(eval).tolist()
feedbacks = df.loc[:, "피드백"].tolist()

# Excel 파일에서 각도 차이와 피드백 텍스트를 각각 리스트로 저장

# 데이터 증강 함수
def augment_data(angles, feedbacks): #각도차이와 피드백을 받아서 데이터를 증강시킴
    augmented_angles = []
    augmented_feedbacks = []
    for angle, feedback in zip(angles, feedbacks): 
        augmented_angles.append(angle)
        augmented_feedbacks.append(feedback)

        for _ in range(3):
            noisy_angle = [a + np.random.normal(0, 0.8) for a in angle]  #원래 각도차이에서 평균이 0 표준편차가 0.8을 더한 새로운 앵글 데이터 증강
            augmented_angles.append(noisy_angle)
            augmented_feedbacks.append(feedback)

    return augmented_angles, augmented_feedbacks

angle_differences, feedbacks = augment_data(angle_differences, feedbacks)

# 데이터 전처리 함수 피드백 데이터를 토큰화 해서 정수 시퀀스로 바꿔줌
def preprocess_data(angles, feedbacks):
    max_length = max(len(angle) for angle in angles) #앵글각도차이 최대길이

    padded_angles = [angle + [0] * (max_length - len(angle)) for angle in angles] #만약 앵글각도차이의 리스트 길이가 최대 앵글 각도차이와 다르면 제로패딩

    angle_tensor = np.array(padded_angles)  #패딩된 앵글 정보들을 array로 바꿈
    angle_sign = np.sign(angle_tensor)  # 각도의 부호(+,-) 정보 추출
    angle_tensor = np.abs(angle_tensor)  #부호를 따로 저장해 두었으므로 절대값을 사용

    tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='', lower=True, oov_token="<UNK>") #토크나이저 함수 필터할 단어는 ''으로 없음으로 두고 lower로 모든 문자를 소문자로, 단어사전에 없는 토큰은 unk로 설정
    tokenizer.fit_on_texts(['<start> ' + f.lower() + ' <end>' for f in feedbacks]) #각 피드백에 시작과 끝에 <start> <end> 토큰 추가
    feedback_tensor = tokenizer.texts_to_sequences(['<start> ' + f.lower() + ' <end>' for f in feedbacks]) #피드백 데이터를 시퀀스로 바꿈
    feedback_tensor = tf.keras.preprocessing.sequence.pad_sequences(feedback_tensor, padding='post') #정수 시퀀스들을 패딩해서 길이를 맞춤 (post로 설정하여 뒤에 0이 붙도록) 앞에 0이 오도록하는것은 pre

    return angle_tensor, angle_sign, feedback_tensor, tokenizer



angle_tensor, angle_sign, feedback_tensor, tokenizer = preprocess_data(angle_differences, feedbacks)
#각도차이 ,      각도의 부호 , 피드백 시퀀스 ,  사용한 토크나이저

# 데이터를 훈련셋과 테스트 셋으로 만듬
X_angle = angle_tensor
X_sign = angle_sign
y = feedback_tensor
X_angle_train, X_angle_test, X_sign_train, X_sign_test, y_train, y_test = train_test_split(
    X_angle, X_sign, y, test_size=0.2, random_state=42)

#s2s 모델 정의
class Seq2SeqModel(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, units): #vocab size= 단어 사전의 단어 개수 , embedding_dim= 단어 임베딩시 사용할 차원의 수 units = lstm을 통과한 출력차원의 수 (dense층의 입력차원)
        super(Seq2SeqModel, self).__init__()
        self.angle_input = Input(shape=(None,)) #input shape을 none로 설정해서 input dim에 제한을 없앰 (timestep: lstm의 개수를 길이에 따라 동적으로 지정) 각도입력 (배치사이즈,타임스탭,feature)input레이어에서 별도 설정없으면 fit시에 배치사이즈가 동적으로 설정
        self.sign_input = Input(shape=(None,))# 부호 입력데이터 생성
        self.decoder_input = Input(shape=(None,))#디코더(피드백) 입력

        self.angle_dense = Dense(units, activation='relu')#dense를 지나서 units의 차원으로 출력 (batchsize,timesteps,feature)를 출력
        self.sign_dense = Dense(units, activation='relu')
        self.concat = Concatenate()

        self.embedding = Embedding(vocab_size, embedding_dim)
        self.encoder = LSTM(units, return_sequences=True, return_state=True)
        self.decoder = LSTM(units, return_sequences=True, return_state=True)
        self.dropout = Dropout(0.3)
        self.dense = Dense(vocab_size, activation='softmax')

    def call(self, inputs, training=False): #output함수
        angle_input, sign_input, decoder_input = inputs #각도차이, 부호 ,피드백을 인풋으로 설정

        angle_features = self.angle_dense(angle_input) #앵글 인풋을 dense층을 거쳐서 units차원으로 feature을 추출
        sign_features = self.sign_dense(sign_input) # 부호데이터를 dense층을 지나게함
        encoder_input = self.concat([angle_features, sign_features]) #앵글 각도와 부호를 콘캣 해서 인코더의 인풋으로 활용

        encoder_output, state_h, state_c = self.encoder(tf.expand_dims(encoder_input, axis=1)) #encoder_input데이터를 배치사이즈,1,timesteps,feature 형태의 차원으로 바꾼후 lstm통과
        #각각의 변수에 (lstm의 모든 출력을 포함하는 텐서, 현재 타임스탭에서의 정보를 포함하는 은닉상태, 장기의존성 학습을 위한 셀 상태)

        decoder_hidden = self.embedding(decoder_input) #피드백 데이터를 디코더 input레이어를 통과시켜 (batchsize,timestep,feature)형태로 나오게 한 후 임배딩
        decoder_output, _, _ = self.decoder(decoder_hidden, initial_state=[state_h, state_c]) #lstm층을 통과시키는데 여기서 initial_state를 인코더에서 받은 초기 상태로 설정
        
        decoder_output = self.dropout(decoder_output, training=training) #디코더 lstm출력을 트레이닝중에는 드랍아웃을 시켜 과적합 방지
        output = self.dense(decoder_output) #디코더 아웃풋을 댄스층을 거쳐 softmax로
        return output

# 하이퍼파라미터 설정
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 256
units = 128
batch_size = 32
epochs = 100

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model = Seq2SeqModel(vocab_size, embedding_dim, units)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#모델 생성 및 컴파일

# 커스텀 콜백정의
class EfficientModelCheckpoint(Callback):
    def __init__(self, patience=10):
        super().__init__()
        self.patience = patience
        self.best_val_loss = float('inf')
        self.best_weights = None
        self.wait = 0

    def on_epoch_end(self, epoch, logs=None):
        current_val_loss = logs.get('val_loss')
        if current_val_loss < self.best_val_loss:
            self.best_val_loss = current_val_loss
            self.best_weights = self.model.get_weights()
            self.wait = 0
            print(f"\nEpoch {epoch+1}: 새로운 최상의 모델 발견 (val_loss: {current_val_loss:.4f})")
        else:
            self.wait += 1
            if self.wait >= self.patience:
                self.model.stop_training = True
                print(f"\n{self.patience} 에포크 동안 개선이 없어 학습을 종료합니다.")
                print(f"최상의 val_loss: {self.best_val_loss:.4f}")
                self.model.set_weights(self.best_weights)

#val loss가 개선되지 않으면 학습을 조기 종료후에 최상의 모델 가중치를 저장

# 콜백 인스턴스 생성
efficient_checkpoint = EfficientModelCheckpoint(patience=10)

# 모델 학습
history = model.fit(
    [X_angle_train, X_sign_train, y_train[:, :-1]], y_train[:, 1:],
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[efficient_checkpoint]
)

# 학습 후 최상의 모델 저장
model.save('best_model', save_format='tf')

# 학습이 완료된 후 최종 모델을 저장합니다.

# 피드백 생성 함수
def generate_feedback(model, tokenizer, angles):
    angle_tensor = np.abs(angles) #각도의 절댓값을 받고
    angle_sign = np.sign(angles) #부호를 받아서
    start_token = tokenizer.word_index['<start>'] #start토큰과 end토큰을 정의
    end_token = tokenizer.word_index['<end>']

    decoder_input = tf.constant([[start_token]]) #시퀀스의 시작을 생성
    result = []

    for _ in range(50): #50번 반복
        predictions = model([np.expand_dims(angle_tensor, 0), np.expand_dims(angle_sign, 0), decoder_input]) #모델에  앵글텐서,앵글 부호 텐서,디코더 인풋 텐서를 입력으로 넣어 입력디코더의 다음 단어를 예측
        predicted_id = tf.argmax(predictions[0, -1, :]) #현재 시퀀스의 마지막 타임스텝에서의 예측 확률 분포를 찾아서 가장 확률이 높은 단어의 인덱스를 저장 
        predicted_id = int(predicted_id) #정수값으로 넣음

        if predicted_id == end_token: #end_token에 도달하면 시퀀스 생성을 종료
            break

        if predicted_id in tokenizer.index_word:
            result.append(tokenizer.index_word[predicted_id]) #predicted_id가 tokenizer.index_word에 존재하면 해당 단어를 result 리스트에 추가
        else: #아니면 unk(oov)추가
            result.append("<UNK>")

        decoder_input = tf.concat([decoder_input, [[predicted_id]]], axis=1) #디코더 인풋에 predicted를 추가해서 다음 단어예측

    return ' '.join(result)

# 학습된 모델을 사용하여 새로운 각도 입력에 대한 피드백을 생성하는 함수

# BLEU 점수 계산 함수
def calculate_bleu(reference, candidate):
    reference = reference.split()
    candidate = candidate.split()
    return sentence_bleu([reference], candidate)

# BLEU 점수를 계산하는 함수, 생성된 피드백에 대한 품질 평가

# 테스트
test_angles = [16, -29, 22, 5, -18, 27, 20, -7]
generated_feedback = generate_feedback(model, tokenizer, test_angles)
print(f"입력 각도: {test_angles}")
print(f"생성된 피드백: {generated_feedback}")

# 모델 평가
test_loss, test_accuracy = model.evaluate([X_angle_test, X_sign_test, y_test[:, :-1]], y_test[:, 1:])
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# 테스트 데이터셋에 대한 모델의 성능을 평가

# BLEU 점수 계산 (전체 테스트 세트에 대해)
bleu_scores = []
for angles, true_feedback in zip(X_angle_test, y_test):
    generated = generate_feedback(model, tokenizer, angles)
    true = ' '.join([tokenizer.index_word[idx] for idx in true_feedback if idx != 0 and idx in tokenizer.index_word])
    bleu_scores.append(calculate_bleu(true, generated))

average_bleu = np.mean(bleu_scores)
print(f"Average BLEU Score: {average_bleu}")

# 전체 테스트 세트에 대해 BLEU 점수를 계산하고 평균값을 매김
# 모델이 생성한 피드백의 전반적인 품질을 평가
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 3.9473 - accuracy: 0.3458
# Epoch 1: 새로운 최상의 모델 발견 (val_loss: 3.3837)
# 8/8 [==============================] - 8s 370ms/step - loss: 3.9473 - accuracy: 0.3458 - val_loss: 3.3837 - val_accuracy: 0.4500
# Epoch 2/100
# 8/8 [==============================] - ETA: 0s - loss: 2.8457 - accuracy: 0.4133
# Epoch 2: 새로운 최상의 모델 발견 (val_loss: 2.2720)
# 8/8 [==============================] - 1s 153ms/step - loss: 2.8457 - accuracy: 0.4133 - val_loss: 2.2720 - val_accuracy: 0.4613
# Epoch 3/100
# 8/8 [==============================] - ETA: 0s - loss: 2.2960 - accuracy: 0.4586
# Epoch 3: 새로운 최상의 모델 발견 (val_loss: 1.9932)
# 8/8 [==============================] - 1s 107ms/step - loss: 2.2960 - accuracy: 0.4586 - val_loss: 1.9932 - val_accuracy: 0.4973
# Epoch 4/100
# 8/8 [==============================] - ETA: 0s - loss: 2.0680 - accuracy: 0.4802
# Epoch 4: 새로운 최상의 모델 발견 (val_loss: 1.8309)
# 8/8 [==============================] - 1s 95ms/step - loss: 2.0680 - accuracy: 0.4802 - val_loss: 1.8309 - val_accuracy: 0.5177
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 1.9405 - accuracy: 0.4940
# Epoch 5: 새로운 최상의 모델 발견 (val_loss: 1.7307)
# 8/8 [==============================] - 1s 82ms/step - loss: 1.9405 - accuracy: 0.4940 - val_loss: 1.7307 - val_accuracy: 0.5355
# Epoch 6/100
# 8/8 [==============================] - ETA: 0s - loss: 1.8469 - accuracy: 0.5032
# Epoch 6: 새로운 최상의 모델 발견 (val_loss: 1.6557)
# 8/8 [==============================] - 1s 86ms/step - loss: 1.8469 - accuracy: 0.5032 - val_loss: 1.6557 - val_accuracy: 0.5333
# Epoch 7/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7748 - accuracy: 0.5121
# Epoch 7: 새로운 최상의 모델 발견 (val_loss: 1.5867)
# 8/8 [==============================] - 1s 96ms/step - loss: 1.7748 - accuracy: 0.5121 - val_loss: 1.5867 - val_accuracy: 0.5516
# Epoch 8/100
# 8/8 [==============================] - ETA: 0s - loss: 1.7120 - accuracy: 0.5278
# Epoch 8: 새로운 최상의 모델 발견 (val_loss: 1.5330)
# 8/8 [==============================] - 1s 83ms/step - loss: 1.7120 - accuracy: 0.5278 - val_loss: 1.5330 - val_accuracy: 0.5806
# Epoch 9/100
# 8/8 [==============================] - ETA: 0s - loss: 1.6489 - accuracy: 0.5448
# Epoch 9: 새로운 최상의 모델 발견 (val_loss: 1.4689)
# 8/8 [==============================] - 1s 90ms/step - loss: 1.6489 - accuracy: 0.5448 - val_loss: 1.4689 - val_accuracy: 0.5785
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 1.5974 - accuracy: 0.5581
# Epoch 10: 새로운 최상의 모델 발견 (val_loss: 1.4120)
# 8/8 [==============================] - 1s 85ms/step - loss: 1.5974 - accuracy: 0.5581 - val_loss: 1.4120 - val_accuracy: 0.6091
# Epoch 11/100
# 8/8 [==============================] - ETA: 0s - loss: 1.5422 - accuracy: 0.5780
# Epoch 11: 새로운 최상의 모델 발견 (val_loss: 1.3524)
# 8/8 [==============================] - 1s 82ms/step - loss: 1.5422 - accuracy: 0.5780 - val_loss: 1.3524 - val_accuracy: 0.6414
# Epoch 12/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4710 - accuracy: 0.6035
# Epoch 12: 새로운 최상의 모델 발견 (val_loss: 1.2911)
# 8/8 [==============================] - 1s 87ms/step - loss: 1.4710 - accuracy: 0.6035 - val_loss: 1.2911 - val_accuracy: 0.6532
# Epoch 13/100
# 8/8 [==============================] - ETA: 0s - loss: 1.4068 - accuracy: 0.6147
# Epoch 13: 새로운 최상의 모델 발견 (val_loss: 1.2128)
# 8/8 [==============================] - 1s 87ms/step - loss: 1.4068 - accuracy: 0.6147 - val_loss: 1.2128 - val_accuracy: 0.6683
# Epoch 14/100
# 8/8 [==============================] - ETA: 0s - loss: 1.3330 - accuracy: 0.6337
# Epoch 14: 새로운 최상의 모델 발견 (val_loss: 1.1325)
# 8/8 [==============================] - 1s 81ms/step - loss: 1.3330 - accuracy: 0.6337 - val_loss: 1.1325 - val_accuracy: 0.6769
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 1.2434 - accuracy: 0.6536
# Epoch 15: 새로운 최상의 모델 발견 (val_loss: 1.0408)
# 8/8 [==============================] - 1s 90ms/step - loss: 1.2434 - accuracy: 0.6536 - val_loss: 1.0408 - val_accuracy: 0.7156
# Epoch 16/100
# 8/8 [==============================] - ETA: 0s - loss: 1.1538 - accuracy: 0.6769
# Epoch 16: 새로운 최상의 모델 발견 (val_loss: 0.9639)
# 8/8 [==============================] - 1s 88ms/step - loss: 1.1538 - accuracy: 0.6769 - val_loss: 0.9639 - val_accuracy: 0.7323
# Epoch 17/100
# 8/8 [==============================] - ETA: 0s - loss: 1.0713 - accuracy: 0.7003
# Epoch 17: 새로운 최상의 모델 발견 (val_loss: 0.8945)
# 8/8 [==============================] - 1s 80ms/step - loss: 1.0713 - accuracy: 0.7003 - val_loss: 0.8945 - val_accuracy: 0.7683
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9997 - accuracy: 0.7199
# Epoch 18: 새로운 최상의 모델 발견 (val_loss: 0.8258)
# 8/8 [==============================] - 1s 151ms/step - loss: 0.9997 - accuracy: 0.7199 - val_loss: 0.8258 - val_accuracy: 0.7694
# Epoch 19/100
# 8/8 [==============================] - ETA: 0s - loss: 0.9352 - accuracy: 0.7308
# Epoch 19: 새로운 최상의 모델 발견 (val_loss: 0.7746)
# 8/8 [==============================] - 1s 139ms/step - loss: 0.9352 - accuracy: 0.7308 - val_loss: 0.7746 - val_accuracy: 0.7833
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8836 - accuracy: 0.7434
# Epoch 20: 새로운 최상의 모델 발견 (val_loss: 0.7278)
# 8/8 [==============================] - 1s 149ms/step - loss: 0.8836 - accuracy: 0.7434 - val_loss: 0.7278 - val_accuracy: 0.7989
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 0.8381 - accuracy: 0.7476
# Epoch 21: 새로운 최상의 모델 발견 (val_loss: 0.6892)
# 8/8 [==============================] - 1s 145ms/step - loss: 0.8381 - accuracy: 0.7476 - val_loss: 0.6892 - val_accuracy: 0.8038
# Epoch 22/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7919 - accuracy: 0.7582
# Epoch 22: 새로운 최상의 모델 발견 (val_loss: 0.6564)
# 8/8 [==============================] - 1s 142ms/step - loss: 0.7919 - accuracy: 0.7582 - val_loss: 0.6564 - val_accuracy: 0.8091
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7573 - accuracy: 0.7659
# Epoch 23: 새로운 최상의 모델 발견 (val_loss: 0.6274)
# 8/8 [==============================] - 1s 101ms/step - loss: 0.7573 - accuracy: 0.7659 - val_loss: 0.6274 - val_accuracy: 0.8124
# Epoch 24/100
# 8/8 [==============================] - ETA: 0s - loss: 0.7258 - accuracy: 0.7739
# Epoch 24: 새로운 최상의 모델 발견 (val_loss: 0.6061)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.7258 - accuracy: 0.7739 - val_loss: 0.6061 - val_accuracy: 0.8194
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.7825
# Epoch 25: 새로운 최상의 모델 발견 (val_loss: 0.5810)
# 8/8 [==============================] - 1s 84ms/step - loss: 0.6939 - accuracy: 0.7825 - val_loss: 0.5810 - val_accuracy: 0.8226
# Epoch 26/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6696 - accuracy: 0.7901
# Epoch 26: 새로운 최상의 모델 발견 (val_loss: 0.5609)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.6696 - accuracy: 0.7901 - val_loss: 0.5609 - val_accuracy: 0.8296
# Epoch 27/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6405 - accuracy: 0.7966
# Epoch 27: 새로운 최상의 모델 발견 (val_loss: 0.5406)
# 8/8 [==============================] - 1s 89ms/step - loss: 0.6405 - accuracy: 0.7966 - val_loss: 0.5406 - val_accuracy: 0.8333
# Epoch 28/100
# 8/8 [==============================] - ETA: 0s - loss: 0.6185 - accuracy: 0.8008
# Epoch 28: 새로운 최상의 모델 발견 (val_loss: 0.5210)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.6185 - accuracy: 0.8008 - val_loss: 0.5210 - val_accuracy: 0.8452
# Epoch 29/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5944 - accuracy: 0.8180
# Epoch 29: 새로운 최상의 모델 발견 (val_loss: 0.5013)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.5944 - accuracy: 0.8180 - val_loss: 0.5013 - val_accuracy: 0.8527
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.8202
# Epoch 30: 새로운 최상의 모델 발견 (val_loss: 0.4862)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.5708 - accuracy: 0.8202 - val_loss: 0.4862 - val_accuracy: 0.8489
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5555 - accuracy: 0.8288
# Epoch 31: 새로운 최상의 모델 발견 (val_loss: 0.4731)
# 8/8 [==============================] - 1s 87ms/step - loss: 0.5555 - accuracy: 0.8288 - val_loss: 0.4731 - val_accuracy: 0.8591
# Epoch 32/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.8335
# Epoch 32: 새로운 최상의 모델 발견 (val_loss: 0.4575)
# 8/8 [==============================] - 1s 87ms/step - loss: 0.5389 - accuracy: 0.8335 - val_loss: 0.4575 - val_accuracy: 0.8591
# Epoch 33/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5206 - accuracy: 0.8380
# Epoch 33: 새로운 최상의 모델 발견 (val_loss: 0.4493)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.5206 - accuracy: 0.8380 - val_loss: 0.4493 - val_accuracy: 0.8602
# Epoch 34/100
# 8/8 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.8395
# Epoch 34: 새로운 최상의 모델 발견 (val_loss: 0.4295)
# 8/8 [==============================] - 1s 91ms/step - loss: 0.5040 - accuracy: 0.8395 - val_loss: 0.4295 - val_accuracy: 0.8731
# Epoch 35/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4761 - accuracy: 0.8563
# Epoch 35: 새로운 최상의 모델 발견 (val_loss: 0.4186)
# 8/8 [==============================] - 1s 84ms/step - loss: 0.4761 - accuracy: 0.8563 - val_loss: 0.4186 - val_accuracy: 0.8710
# Epoch 36/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.8567
# Epoch 36: 새로운 최상의 모델 발견 (val_loss: 0.4078)
# 8/8 [==============================] - 1s 91ms/step - loss: 0.4669 - accuracy: 0.8567 - val_loss: 0.4078 - val_accuracy: 0.8763
# Epoch 37/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4540 - accuracy: 0.8593
# Epoch 37: 새로운 최상의 모델 발견 (val_loss: 0.3933)
# 8/8 [==============================] - 1s 100ms/step - loss: 0.4540 - accuracy: 0.8593 - val_loss: 0.3933 - val_accuracy: 0.8688
# Epoch 38/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4382 - accuracy: 0.8665
# Epoch 38: 새로운 최상의 모델 발견 (val_loss: 0.3813)
# 8/8 [==============================] - 1s 151ms/step - loss: 0.4382 - accuracy: 0.8665 - val_loss: 0.3813 - val_accuracy: 0.8817
# Epoch 39/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4233 - accuracy: 0.8676
# Epoch 39: 새로운 최상의 모델 발견 (val_loss: 0.3723)
# 8/8 [==============================] - 1s 142ms/step - loss: 0.4233 - accuracy: 0.8676 - val_loss: 0.3723 - val_accuracy: 0.8930
# Epoch 40/100
# 8/8 [==============================] - ETA: 0s - loss: 0.4118 - accuracy: 0.8738
# Epoch 40: 새로운 최상의 모델 발견 (val_loss: 0.3651)
# 8/8 [==============================] - 1s 154ms/step - loss: 0.4118 - accuracy: 0.8738 - val_loss: 0.3651 - val_accuracy: 0.8833
# Epoch 41/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.8824
# Epoch 41: 새로운 최상의 모델 발견 (val_loss: 0.3507)
# 8/8 [==============================] - 1s 143ms/step - loss: 0.3950 - accuracy: 0.8824 - val_loss: 0.3507 - val_accuracy: 0.8946
# Epoch 42/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.3799 - accuracy: 0.8858 - val_loss: 0.3644 - val_accuracy: 0.8925
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3803 - accuracy: 0.8825
# Epoch 43: 새로운 최상의 모델 발견 (val_loss: 0.3356)
# 8/8 [==============================] - 1s 84ms/step - loss: 0.3803 - accuracy: 0.8825 - val_loss: 0.3356 - val_accuracy: 0.8909
# Epoch 44/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.8898
# Epoch 44: 새로운 최상의 모델 발견 (val_loss: 0.3268)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.3615 - accuracy: 0.8898 - val_loss: 0.3268 - val_accuracy: 0.9011
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.8966
# Epoch 45: 새로운 최상의 모델 발견 (val_loss: 0.3113)
# 8/8 [==============================] - 1s 89ms/step - loss: 0.3472 - accuracy: 0.8966 - val_loss: 0.3113 - val_accuracy: 0.9043
# Epoch 46/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.9017
# Epoch 46: 새로운 최상의 모델 발견 (val_loss: 0.3068)
# 8/8 [==============================] - 1s 90ms/step - loss: 0.3324 - accuracy: 0.9017 - val_loss: 0.3068 - val_accuracy: 0.9054
# Epoch 47/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3258 - accuracy: 0.9004
# Epoch 47: 새로운 최상의 모델 발견 (val_loss: 0.2985)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.3258 - accuracy: 0.9004 - val_loss: 0.2985 - val_accuracy: 0.9070
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3172 - accuracy: 0.9042
# Epoch 48: 새로운 최상의 모델 발견 (val_loss: 0.2893)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.3172 - accuracy: 0.9042 - val_loss: 0.2893 - val_accuracy: 0.9161
# Epoch 49/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3029 - accuracy: 0.9101
# Epoch 49: 새로운 최상의 모델 발견 (val_loss: 0.2780)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.3029 - accuracy: 0.9101 - val_loss: 0.2780 - val_accuracy: 0.9194
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.9129
# Epoch 50: 새로운 최상의 모델 발견 (val_loss: 0.2756)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.2946 - accuracy: 0.9129 - val_loss: 0.2756 - val_accuracy: 0.9177
# Epoch 51/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.9134
# Epoch 51: 새로운 최상의 모델 발견 (val_loss: 0.2710)
# 8/8 [==============================] - 1s 87ms/step - loss: 0.2901 - accuracy: 0.9134 - val_loss: 0.2710 - val_accuracy: 0.9151
# Epoch 52/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.9179
# Epoch 52: 새로운 최상의 모델 발견 (val_loss: 0.2649)
# 8/8 [==============================] - 1s 84ms/step - loss: 0.2814 - accuracy: 0.9179 - val_loss: 0.2649 - val_accuracy: 0.9172
# Epoch 53/100
# 8/8 [==============================] - 1s 85ms/step - loss: 0.2786 - accuracy: 0.9157 - val_loss: 0.2652 - val_accuracy: 0.9274
# Epoch 54/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2727 - accuracy: 0.9187 - val_loss: 0.2651 - val_accuracy: 0.9156
# Epoch 55/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9200
# Epoch 55: 새로운 최상의 모델 발견 (val_loss: 0.2521)
# 8/8 [==============================] - 1s 87ms/step - loss: 0.2665 - accuracy: 0.9200 - val_loss: 0.2521 - val_accuracy: 0.9220
# Epoch 56/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2549 - accuracy: 0.9272
# Epoch 56: 새로운 최상의 모델 발견 (val_loss: 0.2394)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.2549 - accuracy: 0.9272 - val_loss: 0.2394 - val_accuracy: 0.9328
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9315
# Epoch 57: 새로운 최상의 모델 발견 (val_loss: 0.2264)
# 8/8 [==============================] - 1s 155ms/step - loss: 0.2428 - accuracy: 0.9315 - val_loss: 0.2264 - val_accuracy: 0.9398
# Epoch 58/100
# 8/8 [==============================] - 1s 145ms/step - loss: 0.2363 - accuracy: 0.9339 - val_loss: 0.2340 - val_accuracy: 0.9339
# Epoch 59/100
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2319 - accuracy: 0.9363 - val_loss: 0.2283 - val_accuracy: 0.9371
# Epoch 60/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.9402
# Epoch 60: 새로운 최상의 모델 발견 (val_loss: 0.2209)
# 8/8 [==============================] - 1s 143ms/step - loss: 0.2237 - accuracy: 0.9402 - val_loss: 0.2209 - val_accuracy: 0.9339
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2274 - accuracy: 0.9366
# Epoch 61: 새로운 최상의 모델 발견 (val_loss: 0.2104)
# 8/8 [==============================] - 1s 154ms/step - loss: 0.2274 - accuracy: 0.9366 - val_loss: 0.2104 - val_accuracy: 0.9414
# Epoch 62/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9413
# Epoch 62: 새로운 최상의 모델 발견 (val_loss: 0.2028)
# 8/8 [==============================] - 1s 90ms/step - loss: 0.2158 - accuracy: 0.9413 - val_loss: 0.2028 - val_accuracy: 0.9457
# Epoch 63/100
# 8/8 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9460
# Epoch 63: 새로운 최상의 모델 발견 (val_loss: 0.1995)
# 8/8 [==============================] - 1s 83ms/step - loss: 0.2021 - accuracy: 0.9460 - val_loss: 0.1995 - val_accuracy: 0.9457
# Epoch 64/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9507
# Epoch 64: 새로운 최상의 모델 발견 (val_loss: 0.1897)
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1958 - accuracy: 0.9507 - val_loss: 0.1897 - val_accuracy: 0.9495
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1880 - accuracy: 0.9484
# Epoch 65: 새로운 최상의 모델 발견 (val_loss: 0.1834)
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1880 - accuracy: 0.9484 - val_loss: 0.1834 - val_accuracy: 0.9554
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9559
# Epoch 66: 새로운 최상의 모델 발견 (val_loss: 0.1784)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1761 - accuracy: 0.9559 - val_loss: 0.1784 - val_accuracy: 0.9527
# Epoch 67/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9547
# Epoch 67: 새로운 최상의 모델 발견 (val_loss: 0.1701)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1716 - accuracy: 0.9547 - val_loss: 0.1701 - val_accuracy: 0.9554
# Epoch 68/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9637
# Epoch 68: 새로운 최상의 모델 발견 (val_loss: 0.1626)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1645 - accuracy: 0.9637 - val_loss: 0.1626 - val_accuracy: 0.9559
# Epoch 69/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1634 - accuracy: 0.9602 - val_loss: 0.1681 - val_accuracy: 0.9543
# Epoch 70/100
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1593 - accuracy: 0.9628 - val_loss: 0.1718 - val_accuracy: 0.9500
# Epoch 71/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9605
# Epoch 71: 새로운 최상의 모델 발견 (val_loss: 0.1612)
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1666 - accuracy: 0.9605 - val_loss: 0.1612 - val_accuracy: 0.9575
# Epoch 72/100
# 8/8 [==============================] - 1s 83ms/step - loss: 0.1559 - accuracy: 0.9640 - val_loss: 0.1644 - val_accuracy: 0.9548
# Epoch 73/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9641
# Epoch 73: 새로운 최상의 모델 발견 (val_loss: 0.1431)
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1506 - accuracy: 0.9641 - val_loss: 0.1431 - val_accuracy: 0.9651
# Epoch 74/100
# 8/8 [==============================] - 1s 84ms/step - loss: 0.1472 - accuracy: 0.9657 - val_loss: 0.1449 - val_accuracy: 0.9608
# Epoch 75/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1394 - accuracy: 0.9684
# Epoch 75: 새로운 최상의 모델 발견 (val_loss: 0.1332)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1394 - accuracy: 0.9684 - val_loss: 0.1332 - val_accuracy: 0.9672
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9715
# Epoch 76: 새로운 최상의 모델 발견 (val_loss: 0.1272)
# 8/8 [==============================] - 1s 126ms/step - loss: 0.1320 - accuracy: 0.9715 - val_loss: 0.1272 - val_accuracy: 0.9710
# Epoch 77/100
# 8/8 [==============================] - 1s 149ms/step - loss: 0.1307 - accuracy: 0.9718 - val_loss: 0.1343 - val_accuracy: 0.9651
# Epoch 78/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9749
# Epoch 78: 새로운 최상의 모델 발견 (val_loss: 0.1245)
# 8/8 [==============================] - 1s 149ms/step - loss: 0.1293 - accuracy: 0.9749 - val_loss: 0.1245 - val_accuracy: 0.9704
# Epoch 79/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9722
# Epoch 79: 새로운 최상의 모델 발견 (val_loss: 0.1223)
# 8/8 [==============================] - 1s 157ms/step - loss: 0.1237 - accuracy: 0.9722 - val_loss: 0.1223 - val_accuracy: 0.9742
# Epoch 80/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9761
# Epoch 80: 새로운 최상의 모델 발견 (val_loss: 0.1196)
# 8/8 [==============================] - 1s 122ms/step - loss: 0.1199 - accuracy: 0.9761 - val_loss: 0.1196 - val_accuracy: 0.9715
# Epoch 81/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9763
# Epoch 81: 새로운 최상의 모델 발견 (val_loss: 0.1169)
# 8/8 [==============================] - 1s 150ms/step - loss: 0.1158 - accuracy: 0.9763 - val_loss: 0.1169 - val_accuracy: 0.9769
# Epoch 82/100
# 8/8 [==============================] - 1s 150ms/step - loss: 0.1121 - accuracy: 0.9780 - val_loss: 0.1271 - val_accuracy: 0.9699
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9741
# Epoch 83: 새로운 최상의 모델 발견 (val_loss: 0.1099)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1156 - accuracy: 0.9741 - val_loss: 0.1099 - val_accuracy: 0.9737
# Epoch 84/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1077 - accuracy: 0.9788
# Epoch 84: 새로운 최상의 모델 발견 (val_loss: 0.1073)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1077 - accuracy: 0.9788 - val_loss: 0.1073 - val_accuracy: 0.9747
# Epoch 85/100
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1035 - accuracy: 0.9820 - val_loss: 0.1129 - val_accuracy: 0.9726
# Epoch 86/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9812
# Epoch 86: 새로운 최상의 모델 발견 (val_loss: 0.1019)
# 8/8 [==============================] - 1s 88ms/step - loss: 0.1004 - accuracy: 0.9812 - val_loss: 0.1019 - val_accuracy: 0.9758
# Epoch 87/100
# 8/8 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9821
# Epoch 87: 새로운 최상의 모델 발견 (val_loss: 0.0947)
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1014 - accuracy: 0.9821 - val_loss: 0.0947 - val_accuracy: 0.9785
# Epoch 88/100
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0920 - accuracy: 0.9862 - val_loss: 0.1007 - val_accuracy: 0.9769
# Epoch 89/100
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0928 - accuracy: 0.9833 - val_loss: 0.0981 - val_accuracy: 0.9785
# Epoch 90/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9843
# Epoch 90: 새로운 최상의 모델 발견 (val_loss: 0.0931)
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0905 - accuracy: 0.9843 - val_loss: 0.0931 - val_accuracy: 0.9737
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9825
# Epoch 91: 새로운 최상의 모델 발견 (val_loss: 0.0925)
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0890 - accuracy: 0.9825 - val_loss: 0.0925 - val_accuracy: 0.9785
# Epoch 92/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9858
# Epoch 92: 새로운 최상의 모델 발견 (val_loss: 0.0887)
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0853 - accuracy: 0.9858 - val_loss: 0.0887 - val_accuracy: 0.9806
# Epoch 93/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9847
# Epoch 93: 새로운 최상의 모델 발견 (val_loss: 0.0868)
# 8/8 [==============================] - 1s 118ms/step - loss: 0.0871 - accuracy: 0.9847 - val_loss: 0.0868 - val_accuracy: 0.9855
# Epoch 94/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9855
# Epoch 94: 새로운 최상의 모델 발견 (val_loss: 0.0794)
# 8/8 [==============================] - 2s 249ms/step - loss: 0.0843 - accuracy: 0.9855 - val_loss: 0.0794 - val_accuracy: 0.9871
# Epoch 95/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9863
# Epoch 95: 새로운 최상의 모델 발견 (val_loss: 0.0792)
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0817 - accuracy: 0.9863 - val_loss: 0.0792 - val_accuracy: 0.9823
# Epoch 96/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9860
# Epoch 96: 새로운 최상의 모델 발견 (val_loss: 0.0768)
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0797 - accuracy: 0.9860 - val_loss: 0.0768 - val_accuracy: 0.9860
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9878
# Epoch 97: 새로운 최상의 모델 발견 (val_loss: 0.0702)
# 8/8 [==============================] - 1s 132ms/step - loss: 0.0755 - accuracy: 0.9878 - val_loss: 0.0702 - val_accuracy: 0.9898
# Epoch 98/100
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0723 - accuracy: 0.9887 - val_loss: 0.0708 - val_accuracy: 0.9860
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 0.0669 - accuracy: 0.9917
# Epoch 99: 새로운 최상의 모델 발견 (val_loss: 0.0681)
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0669 - accuracy: 0.9917 - val_loss: 0.0681 - val_accuracy: 0.9898
# Epoch 100/100
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0676 - accuracy: 0.9919 - val_loss: 0.0707 - val_accuracy: 0.9855
# 입력 각도: [16, -29, 22, 5, -18, 27, 20, -7]
# 생성된 피드백: "오른쪽 팔꿈치와 오른쪽 무릎을 더 구부려주시고, 왼쪽 팔꿈치는 더 펴주세요.오른쪽 발목을 더 펴주시고 왼쪽 발목과 오른쪽 골반은 더 구부려주세요."
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0594 - accuracy: 0.9885
# Test Loss: 0.05939669907093048
# Test Accuracy: 0.9885398745536804
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Average BLEU Score: 0.4499625694704042
